# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import bqplot
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import sklearn

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/instacart-market-basket-analysis/products.csv
# /kaggle/input/instacart-market-basket-analysis/departments.csv
# /kaggle/input/instacart-market-basket-analysis/aisles.csv
# /kaggle/input/instacart-market-basket-analysis/order_products__prior.csv
# /kaggle/input/instacart-market-basket-analysis/orders.csv
# /kaggle/input/instacart-market-basket-analysis/order_products__train.csv

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
order_products_train_df = pd.read_csv("../input/instacart-market-basket-analysis/order_products__train.csv")
order_products_prior_df = pd.read_csv("../input/instacart-market-basket-analysis/order_products__prior.csv")
orders_df = pd.read_csv("../input/instacart-market-basket-analysis/orders.csv")
products_df = pd.read_csv("../input/instacart-market-basket-analysis/products.csv")
aisles_df = pd.read_csv("../input/instacart-market-basket-analysis/aisles.csv")
departments_df = pd.read_csv("../input/instacart-market-basket-analysis/departments.csv")
print("Setup Complete")
# Out:
# Setup Complete

# %%
order_products_train_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
products_df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
aisles_df.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
departments_df.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
# merging csv files
# what day of the week is 1 in order_dow? Sunday or Monday?
# reordered appears to work in binary 1s and 0s. 1 means yes?
# add_to_cart_order refers to the order in which the product was added to the cart.
# the amount of each product added to each order/cart is not provided.

order_products_prior_df = pd.merge(order_products_prior_df, products_df, on='product_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, orders_df, on='order_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, aisles_df, on='aisle_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, departments_df, on='department_id', how='left')
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id  user_id eval_set  order_number  order_dow  \
# 0        86             16   202279    prior             3          5
# 1        83              4   202279    prior             3          5
# 2       104             13   202279    prior             3          5
# 3        19             13   202279    prior             3          5
# 4        17             13   202279    prior             3          5
#
#    order_hour_of_day  days_since_prior_order               aisle  department
# 0                  9                     8.0                eggs  dairy eggs
# 1                  9                     8.0    fresh vegetables     produce
# 2                  9                     8.0   spices seasonings      pantry
# 3                  9                     8.0       oils vinegars      pantry
# 4                  9                     8.0  baking ingredients      pantry

# %%
order_products_prior_df['product_id'] == 33120
# Out:
# 0            True
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 32434484    False
# 32434485    False
# 32434486    False
# 32434487    False
# 32434488    False
# Name: product_id, Length: 32434489, dtype: bool

# %%
# sorts out product with the product id of 33120
# loc gets rows with particular labels in it
egg_whites_order_info = order_products_prior_df.loc[order_products_prior_df['product_id'] == 33120, :]

# %%
# All egg whites purchased on a Sunday or Monday (what the first day of the week is).
    # While not super useful now, it might be something to keep in mind. Also, this is currently not sorted in any way.
# Data not given: is the week beginning on Sunday or Monday for order_dow? 
# Interesting idea: making a chart that sorts orders by order_dow.
egg_whites_order_info.loc[egg_whites_order_info['order_dow'] == 1, :]
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 6635           689       33120                  4          1
# 8678           901       33120                  3          1
# 17976         1887       33120                  6          1
# 25416         2652       33120                  1          1
# 28266         2929       33120                  1          0
# ...            ...         ...                ...        ...
# 32363828   3413704       33120                  7          0
# 32406133   3418121       33120                  3          1
# 32413994   3418959       33120                  4          1
# 32427659   3420373       33120                 11          0
# 32430947   3420711       33120                  8          0
#
#                 product_name  aisle_id  department_id  user_id eval_set  \
# 6635      Organic Egg Whites        86             16   108932    prior
# 8678      Organic Egg Whites        86             16   160657    prior
# 17976     Organic Egg Whites        86             16    25085    prior
# 25416     Organic Egg Whites        86             16    37557    prior
# 28266     Organic Egg Whites        86             16   173056    prior
# ...                      ...       ...            ...      ...      ...
# 32363828  Organic Egg Whites        86             16    45486    prior
# 32406133  Organic Egg Whites        86             16    71506    prior
# 32413994  Organic Egg Whites        86             16     4181    prior
# 32427659  Organic Egg Whites        86             16   103838    prior
# 32430947  Organic Egg Whites        86             16    75367    prior
#
#           order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 6635                16          1                 13                     3.0
# 8678                31          1                 23                     8.0
# 17976               78          1                 10                     3.0
# 25416               15          1                 14                    21.0
# 28266                4          1                 10                    21.0
# ...                ...        ...                ...                     ...
# 32363828             1          1                 18                     NaN
# 32406133            12          1                 11                     6.0
# 32413994             6          1                 14                    30.0
# 32427659             5          1                 16                     9.0
# 32430947             9          1                 16                    11.0
#
#          aisle  department
# 6635      eggs  dairy eggs
# 8678      eggs  dairy eggs
# 17976     eggs  dairy eggs
# 25416     eggs  dairy eggs
# 28266     eggs  dairy eggs
# ...        ...         ...
# 32363828  eggs  dairy eggs
# 32406133  eggs  dairy eggs
# 32413994  eggs  dairy eggs
# 32427659  eggs  dairy eggs
# 32430947  eggs  dairy eggs
#
# [3336 rows x 15 columns]

# %%
# orders the egg whites orders by ascending value of user id (user id 155 likes the egg whites)
sorted_egg_whites = egg_whites_order_info.sort_values('user_id', ascending = True)
sorted_egg_whites
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 26925364   2839132       33120                  5          1
# 53314         5640       33120                  9          1
# 11874203   1253654       33120                  5          1
# 2780323     293417       33120                  6          1
# 29425265   3103333       33120                  5          1
# ...            ...         ...                ...        ...
# 5802763     612512       33120                  6          0
# 538653       56974       33120                 23          0
# 14898254   1571959       33120                  7          0
# 18106412   1909878       33120                  1          1
# 17786318   1875862       33120                  6          1
#
#                 product_name  aisle_id  department_id  user_id eval_set  \
# 26925364  Organic Egg Whites        86             16      155    prior
# 53314     Organic Egg Whites        86             16      155    prior
# 11874203  Organic Egg Whites        86             16      155    prior
# 2780323   Organic Egg Whites        86             16      155    prior
# 29425265  Organic Egg Whites        86             16      155    prior
# ...                      ...       ...            ...      ...      ...
# 5802763   Organic Egg Whites        86             16   206174    prior
# 538653    Organic Egg Whites        86             16   206194    prior
# 14898254  Organic Egg Whites        86             16   206200    prior
# 18106412  Organic Egg Whites        86             16   206200    prior
# 17786318  Organic Egg Whites        86             16   206200    prior
#
#           order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 26925364            21          5                  2                    30.0
# 53314               15          2                  0                    28.0
# 11874203            16          0                 21                    12.0
# 2780323             18          0                 21                    19.0
# 29425265             9          1                 14                    26.0
# ...                ...        ...                ...                     ...
# 5802763             49          1                 21                     6.0
# 538653              11          5                  0                    30.0
# 14898254            11          5                  0                     4.0
# 18106412            23          0                 19                     1.0
# 17786318            13          3                 14                     4.0
#
#          aisle  department
# 26925364  eggs  dairy eggs
# 53314     eggs  dairy eggs
# 11874203  eggs  dairy eggs
# 2780323   eggs  dairy eggs
# 29425265  eggs  dairy eggs
# ...        ...         ...
# 5802763   eggs  dairy eggs
# 538653    eggs  dairy eggs
# 14898254  eggs  dairy eggs
# 18106412  eggs  dairy eggs
# 17786318  eggs  dairy eggs
#
# [19400 rows x 15 columns]

# %%
# gives the first 15 rows of the previous chart. While the data in this chart isn't the most useful
    # it is useful in that I definitely will need to use iloc later. So this is more for myself than anything.
# iloc gets index position
# What is the difference between .head() and .iloc[]? So far, they appear to be interchangeable.
# Correction from earlier block: User 155 loves egg whites. (total of 14 separate orders that began on their 2nd order.)
sorted_egg_whites.iloc[0:15]
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 26925364   2839132       33120                  5          1
# 53314         5640       33120                  9          1
# 11874203   1253654       33120                  5          1
# 2780323     293417       33120                  6          1
# 29425265   3103333       33120                  5          1
# 6314069     666435       33120                  6          1
# 30553244   3222720       33120                 10          1
# 18942030   1997753       33120                  5          1
# 32376729   3415043       33120                  9          1
# 13625310   1438105       33120                  7          1
# 12282327   1296427       33120                  5          1
# 2443853     257761       33120                  8          1
# 8886097     938110       33120                  9          1
# 1162291     122604       33120                  6          0
# 6946693     733465       33120                  3          0
#
#                 product_name  aisle_id  department_id  user_id eval_set  \
# 26925364  Organic Egg Whites        86             16      155    prior
# 53314     Organic Egg Whites        86             16      155    prior
# 11874203  Organic Egg Whites        86             16      155    prior
# 2780323   Organic Egg Whites        86             16      155    prior
# 29425265  Organic Egg Whites        86             16      155    prior
# 6314069   Organic Egg Whites        86             16      155    prior
# 30553244  Organic Egg Whites        86             16      155    prior
# 18942030  Organic Egg Whites        86             16      155    prior
# 32376729  Organic Egg Whites        86             16      155    prior
# 13625310  Organic Egg Whites        86             16      155    prior
# 12282327  Organic Egg Whites        86             16      155    prior
# 2443853   Organic Egg Whites        86             16      155    prior
# 8886097   Organic Egg Whites        86             16      155    prior
# 1162291   Organic Egg Whites        86             16      155    prior
# 6946693   Organic Egg Whites        86             16      204    prior
#
#           order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 26925364            21          5                  2                    30.0
# 53314               15          2                  0                    28.0
# 11874203            16          0                 21                    12.0
# 2780323             18          0                 21                    19.0
# 29425265             9          1                 14                    26.0
# 6314069              6          1                 13                     8.0
# 30553244             8          3                 14                    30.0
# 18942030            14          2                 22                    13.0
# 32376729            13          3                  0                    22.0
# 13625310            11          1                 16                     7.0
# 12282327             7          4                 15                    17.0
# 2443853              4          1                 10                    22.0
# 8886097             17          2                 18                    23.0
# 1162291              2          4                 20                    10.0
# 6946693             28          6                 13                     6.0
#
#          aisle  department
# 26925364  eggs  dairy eggs
# 53314     eggs  dairy eggs
# 11874203  eggs  dairy eggs
# 2780323   eggs  dairy eggs
# 29425265  eggs  dairy eggs
# 6314069   eggs  dairy eggs
# 30553244  eggs  dairy eggs
# 18942030  eggs  dairy eggs
# 32376729  eggs  dairy eggs
# 13625310  eggs  dairy eggs
# 12282327  eggs  dairy eggs
# 2443853   eggs  dairy eggs
# 8886097   eggs  dairy eggs
# 1162291   eggs  dairy eggs
# 6946693   eggs  dairy eggs

# %%
# This is how many times a specific product is on an order
# well, this looks weird, but despite the count being in every column, the count is correct.
# is there a nicer way of coding this that's less messy? Yes, see next block.
# also, there are 49,677 unique product names in this dataset.
product_count = order_products_prior_df.groupby('product_name').count()
product_count
# Out:
#                                                     order_id  product_id  \
# product_name
# #2 Coffee Filters                                        777         777
# #2 Cone White Coffee Filters                              13          13
# #2 Mechanical Pencils                                      8           8
# #4 Natural Brown Coffee Filters                          241         241
# & Go! Hazelnut Spread + Pretzel Sticks                   164         164
# ...                                                      ...         ...
# with Xylitol Unwrapped Original Flavor 50 Stick...        37          37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...        55          55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...        68          68
# with a Splash of Mango Coconut Water                      23          23
# with a Splash of Pineapple Coconut Water                  53          53
#
#                                                     add_to_cart_order  \
# product_name
# #2 Coffee Filters                                                 777
# #2 Cone White Coffee Filters                                       13
# #2 Mechanical Pencils                                               8
# #4 Natural Brown Coffee Filters                                   241
# & Go! Hazelnut Spread + Pretzel Sticks                            164
# ...                                                               ...
# with Xylitol Unwrapped Original Flavor 50 Stick...                 37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...                 55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...                 68
# with a Splash of Mango Coconut Water                               23
# with a Splash of Pineapple Coconut Water                           53
#
#                                                     reordered  aisle_id  \
# product_name
# #2 Coffee Filters                                         777       777
# #2 Cone White Coffee Filters                               13        13
# #2 Mechanical Pencils                                       8         8
# #4 Natural Brown Coffee Filters                           241       241
# & Go! Hazelnut Spread + Pretzel Sticks                    164       164
# ...                                                       ...       ...
# with Xylitol Unwrapped Original Flavor 50 Stick...         37        37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...         55        55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...         68        68
# with a Splash of Mango Coconut Water                       23        23
# with a Splash of Pineapple Coconut Water                   53        53
#
#                                                     department_id  user_id  \
# product_name
# #2 Coffee Filters                                             777      777
# #2 Cone White Coffee Filters                                   13       13
# #2 Mechanical Pencils                                           8        8
# #4 Natural Brown Coffee Filters                               241      241
# & Go! Hazelnut Spread + Pretzel Sticks                        164      164
# ...                                                           ...      ...
# with Xylitol Unwrapped Original Flavor 50 Stick...             37       37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...             55       55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...             68       68
# with a Splash of Mango Coconut Water                           23       23
# with a Splash of Pineapple Coconut Water                       53       53
#
#                                                     eval_set  order_number  \
# product_name
# #2 Coffee Filters                                        777           777
# #2 Cone White Coffee Filters                              13            13
# #2 Mechanical Pencils                                      8             8
# #4 Natural Brown Coffee Filters                          241           241
# & Go! Hazelnut Spread + Pretzel Sticks                   164           164
# ...                                                      ...           ...
# with Xylitol Unwrapped Original Flavor 50 Stick...        37            37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...        55            55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...        68            68
# with a Splash of Mango Coconut Water                      23            23
# with a Splash of Pineapple Coconut Water                  53            53
#
#                                                     order_dow  \
# product_name
# #2 Coffee Filters                                         777
# #2 Cone White Coffee Filters                               13
# #2 Mechanical Pencils                                       8
# #4 Natural Brown Coffee Filters                           241
# & Go! Hazelnut Spread + Pretzel Sticks                    164
# ...                                                       ...
# with Xylitol Unwrapped Original Flavor 50 Stick...         37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...         55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...         68
# with a Splash of Mango Coconut Water                       23
# with a Splash of Pineapple Coconut Water                   53
#
#                                                     order_hour_of_day  \
# product_name
# #2 Coffee Filters                                                 777
# #2 Cone White Coffee Filters                                       13
# #2 Mechanical Pencils                                               8
# #4 Natural Brown Coffee Filters                                   241
# & Go! Hazelnut Spread + Pretzel Sticks                            164
# ...                                                               ...
# with Xylitol Unwrapped Original Flavor 50 Stick...                 37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...                 55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...                 68
# with a Splash of Mango Coconut Water                               23
# with a Splash of Pineapple Coconut Water                           53
#
#                                                     days_since_prior_order  \
# product_name
# #2 Coffee Filters                                                      731
# #2 Cone White Coffee Filters                                            13
# #2 Mechanical Pencils                                                    8
# #4 Natural Brown Coffee Filters                                        230
# & Go! Hazelnut Spread + Pretzel Sticks                                 153
# ...                                                                    ...
# with Xylitol Unwrapped Original Flavor 50 Stick...                      35
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...                      49
# with Xylitol Watermelon Twist 18 Sticks Sugar F...                      64
# with a Splash of Mango Coconut Water                                    23
# with a Splash of Pineapple Coconut Water                                51
#
#                                                     aisle  department
# product_name
# #2 Coffee Filters                                     777         777
# #2 Cone White Coffee Filters                           13          13
# #2 Mechanical Pencils                                   8           8
# #4 Natural Brown Coffee Filters                       241         241
# & Go! Hazelnut Spread + Pretzel Sticks                164         164
# ...                                                   ...         ...
# with Xylitol Unwrapped Original Flavor 50 Stick...     37          37
# with Xylitol Unwrapped Spearmint 50 Sticks Suga...     55          55
# with Xylitol Watermelon Twist 18 Sticks Sugar F...     68          68
# with a Splash of Mango Coconut Water                   23          23
# with a Splash of Pineapple Coconut Water               53          53
#
# [49677 rows x 14 columns]

# %%
# quick test to check count
mech_pencil_orders = order_products_prior_df.loc[order_products_prior_df['product_name'] == '#2 Mechanical Pencils', :]
mech_pencil_orders.product_name.count()
# Out:
# 8

# %%
# Looking for null values
# I'm beginning to think that axis = 0 refers to columns and axis = 1 means rows
# This may mean that days_since_prior_order may have null values

null_value_columns = order_products_prior_df.isnull().any(axis = 0)
print(null_value_columns)
# Out:
# order_id                  False
# product_id                False
# add_to_cart_order         False
# reordered                 False
# product_name              False
# aisle_id                  False
# department_id             False
# user_id                   False
# eval_set                  False
# order_number              False
# order_dow                 False
# order_hour_of_day         False
# days_since_prior_order     True
# aisle                     False
# department                False
# dtype: bool

# %%
# list of all rows containing a null value. In this case, the nulls appear to be in days_since_prior_order.
# This makes sense since a new customer wouldn't have an order prior to their first.
# This means there are likely over 2 million new customers in this dataset. See row count of 2,078,068 at bottom.
null_value_rows = order_products_prior_df.isnull().any(axis = 1)
order_products_prior_df[null_value_rows]
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 175             20       35430                  1          0
# 176             20       47485                  2          0
# 177             20        7419                  3          0
# 178             20        5112                  4          0
# 179             20       33452                  5          0
# ...            ...         ...                ...        ...
# 32434467   3421081       32299                  3          0
# 32434468   3421081        3060                  4          0
# 32434469   3421081       20539                  5          0
# 32434470   3421081       35221                  6          0
# 32434471   3421081       12861                  7          0
#
#                                                product_name  aisle_id  \
# 175                                            Nilla Wafers        61
# 176                             Mini Chocolate Chip Waffles        52
# 177                                Sweet Red Grape Tomatoes        83
# 178            Danimals Swingin' Strawberry Banana Smoothie       120
# 179                                Fruit Punch Sports Drink        64
# ...                                                     ...       ...
# 32434467                                      Dijon Mustard        72
# 32434468                          Pepper Jack Cheese Slices        21
# 32434469       Healthy Kids Chicken Alphabet Condensed Soup        69
# 32434470                               Lime Sparkling Water       115
# 32434471  Farmer’s Market Vine Ripened Tomato & Basil Hu...        67
#
#           department_id  user_id eval_set  order_number  order_dow  \
# 175                  19   182912    prior             1          6
# 176                   1   182912    prior             1          6
# 177                   4   182912    prior             1          6
# 178                  16   182912    prior             1          6
# 179                   7   182912    prior             1          6
# ...                 ...      ...      ...           ...        ...
# 32434467             13   117076    prior             1          3
# 32434468             16   117076    prior             1          3
# 32434469             15   117076    prior             1          3
# 32434470              7   117076    prior             1          3
# 32434471             20   117076    prior             1          3
#
#           order_hour_of_day  days_since_prior_order  \
# 175                      17                     NaN
# 176                      17                     NaN
# 177                      17                     NaN
# 178                      17                     NaN
# 179                      17                     NaN
# ...                     ...                     ...
# 32434467                 11                     NaN
# 32434468                 11                     NaN
# 32434469                 11                     NaN
# 32434470                 11                     NaN
# 32434471                 11                     NaN
#
#                                   aisle    department
# 175                       cookies cakes        snacks
# 176                    frozen breakfast        frozen
# 177                    fresh vegetables       produce
# 178                              yogurt    dairy eggs
# 179                energy sports drinks     beverages
# ...                                 ...           ...
# 32434467                     condiments        pantry
# 32434468                packaged cheese    dairy eggs
# 32434469            soup broth bouillon  canned goods
# 32434470  water seltzer sparkling water     beverages
# 32434471           fresh dips tapenades          deli
#
# [2078068 rows x 15 columns]

# %%
# shows unique product names
# semi-failed attempt at data cleaning
# this was an attempt to make sure everything is spelled correctly, but that didn't work since I can't see all the names in the list in Kaggle.
unique_product_names = order_products_prior_df['product_name'].unique()
unique_product_names
# Out:
# array(['Organic Egg Whites', 'Michigan Organic Kale', 'Garlic Powder',
#        ..., 'Piquillo & Jalapeno Bruschetta', 'Original Jerky',
#        'Flatbread Pizza All Natural'], dtype=object)

# %%
# getting a single row for each order_id in prior set, not training set
# useful for seeing order_id with the order_dow, order_hour_of_day, and days_since_prior_order

order_id_groups = order_products_prior_df.groupby('order_id').first()
order_id_sorted_groups = order_id_groups.sort_values('order_id', ascending = True)
order_id_sorted_groups
# Out:
#           product_id  add_to_cart_order  reordered  \
# order_id
# 2              33120                  1          1
# 3              33754                  1          1
# 4              46842                  1          0
# 5              13176                  1          1
# 6              40462                  1          0
# ...              ...                ...        ...
# 3421079        30136                  1          0
# 3421080        27845                  1          1
# 3421081        38185                  1          0
# 3421082        17279                  1          1
# 3421083         7854                  1          0
#
#                                                product_name  aisle_id  \
# order_id
# 2                                        Organic Egg Whites        86
# 3         Total 2% with Strawberry Lowfat Greek Strained...       120
# 4                                   Plain Pre-Sliced Bagels        93
# 5                                    Bag of Organic Bananas        24
# 6                                                   Cleanse        31
# ...                                                     ...       ...
# 3421079                                       Moisture Soap        25
# 3421080                                  Organic Whole Milk        84
# 3421081                Hint of Lime Flavored Tortilla Chips       107
# 3421082                        Fresh 99% Lean Ground Turkey        49
# 3421083                           Freeze Dried Mango Slices       117
#
#           department_id  user_id eval_set  order_number  order_dow  \
# order_id
# 2                    16   202279    prior             3          5
# 3                    16   205970    prior            16          5
# 4                     3   178520    prior            36          1
# 5                     4   156122    prior            42          6
# 6                     7    22352    prior             4          1
# ...                 ...      ...      ...           ...        ...
# 3421079              11   108687    prior             6          1
# 3421080              16    52726    prior             2          1
# 3421081              19   117076    prior             1          3
# 3421082              12   175185    prior            23          2
# 3421083              19    25247    prior            24          2
#
#           order_hour_of_day  days_since_prior_order                   aisle  \
# order_id
# 2                         9                     8.0                    eggs
# 3                        17                    12.0                  yogurt
# 4                         9                     7.0        breakfast bakery
# 5                        16                     9.0            fresh fruits
# 6                        12                    30.0            refrigerated
# ...                     ...                     ...                     ...
# 3421079                  13                     0.0                    soap
# 3421080                  11                     2.0                    milk
# 3421081                  11                     NaN          chips pretzels
# 3421082                  18                     4.0        packaged poultry
# 3421083                   6                    21.0  nuts seeds dried fruit
#
#              department
# order_id
# 2            dairy eggs
# 3            dairy eggs
# 4                bakery
# 5               produce
# 6             beverages
# ...                 ...
# 3421079   personal care
# 3421080      dairy eggs
# 3421081          snacks
# 3421082    meat seafood
# 3421083          snacks
#
# [3214874 rows x 14 columns]

# %%
# Well, this way was easier than the prior block. This includes training data, though.
# I organized it to makes sure I wasn't getting duplicates of order ids
orders_df.sort_values('order_id', ascending = True)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 1868044         1   112108    train             4          4
# 3355525         2   202279    prior             3          5
# 3417191         3   205970    prior            16          5
# 2958007         4   178520    prior            36          1
# 2593373         5   156122    prior            42          6
# ...           ...      ...      ...           ...        ...
# 1809968   3421079   108687    prior             6          1
# 877324    3421080    52726    prior             2          1
# 1949724   3421081   117076    prior             1          3
# 2903252   3421082   175185    prior            23          2
# 419472    3421083    25247    prior            24          2
#
#          order_hour_of_day  days_since_prior_order
# 1868044                 10                     9.0
# 3355525                  9                     8.0
# 3417191                 17                    12.0
# 2958007                  9                     7.0
# 2593373                 16                     9.0
# ...                    ...                     ...
# 1809968                 13                     0.0
# 877324                  11                     2.0
# 1949724                 11                     NaN
# 2903252                 18                     4.0
# 419472                   6                    21.0
#
# [3421083 rows x 7 columns]

# %%
plt.figure(figsize = (15,8))
sns.countplot(x = 'days_since_prior_order', data = orders_df)
plt.ylabel('Count')
plt.xlabel('Days since prior order')
plt.title('Frequency of days since prior order')
# Out:
# Text(0.5, 1.0, 'Frequency of days since prior order')

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = "order_hour_of_day", data = orders_df)
plt.ylabel('Count')
plt.xlabel('Hour of day')
plt.title("Frequency of orders by hour of day")
# Out:
# Text(0.5, 1.0, 'Frequency of orders by hour of day')

# %%
# Info learned: days of the week start from 0 and go to 6. Does not start on 1 like originally thought.
# Still unknown if 0 represents Sunday or Monday
# counts each individual order including orders from the training data as well as prior data.

plt.figure(figsize = (12,8))
sns.countplot(x = 'order_dow', data = orders_df)
plt.ylabel('Count')
plt.xlabel('Day of the week')
plt.title('Frequency of orders each day of the week')
# Out:
# Text(0.5, 1.0, 'Frequency of orders each day of the week')
